# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="darkgrid")

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot( x="sepal_length", y="sepal_width",color="r",data=df)

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip", data=tips,hue="smoker", style="sex",)

# %%
sns.relplot(x="total_bill", y="tip", data=tips,hue="smoker", style="size",)

# %%
sns.relplot(x="total_bill", y="tip",hue="size", data=tips,palette="ch:r=0.8, l= 0.98")

# %%
sns.relplot(x="total_bill", y="tip",hue="smoker", size="size", data=tips)

# %%
sns.relplot(x="total_bill", y="tip",hue="smoker", size="size", data=tips)

# %%
sns.relplot(x="total_bill", y="tip",hue="smoker", size="size", data=tips,kind="line")

# %%
fmri=sns.load_dataset ("fmri")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri, kind="line", ci=False)

# %%
sns.relplot(x="timepoint",y="signal",data=fmri, kind="line", ci="sd")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,hue="event",kind="line", ci="sd")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,hue="region",style="event",kind="line", ci="sd")

# %%
sns.relplot(x="timepoint",y="signal", data=fmri, hue="region",markers=True,kind="line",style="event")

# %%
dots=sns.load_dataset("dots").query("align=='dots'")

# %%
dots.tail()
# Out:
#     align choice  time  coherence  firing_rate
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057

# %%
sns.relplot(x="time", y="firing_rate", hue="coherence", data=dots, kind="line", style="choice")

# %%
sns.relplot(x="total_bill",y="tip", hue="smoker", data=tips, col="time")

# %%
sns.relplot(x="total_bill",y="tip", hue="smoker", data=tips, col="size",)

# %%
sns.relplot(x="total_bill",y="tip", hue="smoker", data=tips, col="size",col_wrap=3)

# %%
sns.lineplot(x="timepoint",y="signal",hue="region", data=fmri,marker=True,err_style="bars")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="total_bill", y="day", data=tips)

# %%
sns.catplot(x="total_bill", y="day", data=tips, jitter=False)

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm",hue="size")

# %%
g=sns.catplot(x="day", y="total_bill", data=tips, kind="violin",inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips,ax=g.ax,size=3,color="k")

# %%
from numpy.random import randn

# %%
d=randn(1000000)

# %%
sns.distplot(d,kde=True, hist=False,rug=False)

# %%
 sns.jointplot(x="tip", y="total_bill", data=tips)

# %%
 sns.jointplot(x="tip", y="total_bill", data=tips, kind="kde")

# %%
iris=sns.load_dataset("iris")

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x="total_bill", y="tip",data=tips)
